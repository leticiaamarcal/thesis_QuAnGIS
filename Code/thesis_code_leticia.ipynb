# %% [markdown]
# # Similarity measures and word subtraction
# Letícia Marçal Russo 0664618

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from nltk.metrics.distance import edit_distance
from sklearn.metrics.pairwise import cosine_similarity
from itertools import combinations
import itertools
from sklearn.feature_extraction.text import TfidfVectorizer, ENGLISH_STOP_WORDS
import nltk
from nltk.tree import Tree
from zss import simple_distance, Node
from sklearn.preprocessing import MinMaxScaler, normalize
from gensim.models import Word2Vec
from collections import Counter

# %%
### SBERT similarity on questions ###

# Load the SBERT model for sentence similarity
model_BERT = SentenceTransformer('bert-base-nli-mean-tokens')

# Define a function to calculate the sentence similarity using SBERT
def calculate_sentence_sim_SBERT(sent1, sent2):
    embeddings = model_BERT.encode([sent1, sent2])
    similarity = cosine_similarity(embeddings)[0][1]
    
    # Rescale the similarity value to a range of 0 to 1
    similarity = (similarity + 1) / 2
        
    return similarity

# %%
### Tree Edit Distance on parse trees ###

# Define function to convert a NLTK tree to node objects
def parse_tree_to_nodes(tree):
    if isinstance(tree, str):
        return Node(tree)
    else:
        children = [parse_tree_to_nodes(child) for child in tree]
        return Node(tree.label(), children)

def count_nodes(node):
    if node is None:
        return 0
    count = 1
    for child in node.children:
        count += count_nodes(child)
    return count


# Define a function to calculate the Tree Edit Distance
def calculate_tree_edit_distance(tree1, tree2):
    # Parse the tree strings into NLTK Tree objects
    tree1 = Tree.fromstring(tree1)
    tree2 = Tree.fromstring(tree2)

    # Convert the NLTK Tree objects to Node objects
    root1 = parse_tree_to_nodes(tree1)
    root2 = parse_tree_to_nodes(tree2)

    # Calculate the tree edit distance
    distance = simple_distance(root1, root2)

    # Count the nodes in the trees
    tree1_size = count_nodes(root1)
    tree2_size = count_nodes(root2)

    # Scale the distance to obtain the actual edit distance
    actual_distance = distance / (tree1_size + tree2_size)

    return actual_distance

# %%
### Word subtraction ### 

# Define function for word subtraction 
def subtract_nodes(nodes1, nodes2):
    nodes1 = [node.strip() for node in nodes1]
    nodes2 = [node.strip() for node in nodes2]

    nodes1_counter = Counter(nodes1)
    nodes2_counter = Counter(nodes2)

    not_common_nodes_counter = nodes1_counter - nodes2_counter
    not_common_nodes = list(not_common_nodes_counter.elements())

    return not_common_nodes

# %%
### Function to create pairwise comparison and apply the three analysis ###

def pairwise_analysis(df):
    output_rows = []
    
    # Get the parse trees from the df column
    parse_trees = df['parse_tree'].tolist()
    
    # Iterate over unique tasks 
    tasks = df['task'].unique()
    for task in tasks:
        task_df = df[df['task'] == task]
        combinations = list(itertools.combinations(task_df.index, 2))

        # Perform pairwise comparison within the task
        for idx1, idx2 in combinations:
            row1 = task_df.loc[idx1]
            row2 = task_df.loc[idx2]
            
            # Calculate question similarity SBERT
            question_sim_SBERT = calculate_sentence_sim_SBERT(row1['question'], row2['question'])
            
            # Calculate TED
            parse_tree_dist = calculate_tree_edit_distance(row1['parse_tree'], row2['parse_tree'])

            # Calculate question subtraction
            question1_words = row1['question'].split()
            question2_words = row2['question'].split()
            question_subtraction = [word for word in question1_words if word not in question2_words]

            # Calculate nodes subtraction
            nodes1 = row1['nodes'].split(',')
            nodes2 = row2['nodes'].split(',')
            nodes_subtraction = subtract_nodes(nodes1, nodes2)
            
            # Create new columns in the df
            output_rows.append({
                'task': row1['task'],
                'question1': row1['question'],
                'question2': row2['question'],
                'parse_tree1': row1['parse_tree'],
                'parse_tree2': row2['parse_tree'],
                'nodes1': row1['nodes'],
                'nodes2': row2['nodes'],
                'question_sim_SBERT': question_sim_SBERT,
                'parse_tree_dist': parse_tree_dist,
                'question_subtraction': ' '.join(question_subtraction),
                'nodes_subtraction': nodes_subtraction
            })

    output_df = pd.DataFrame(output_rows)
    return output_df

# %%
# Read the questions + parse tree from the XLSX file into a pandas df
question_df = pd.read_excel("questions_parsetree_final.xlsx", engine = "openpyxl")

# %%
# Call the pairwise_analysis function 
output_df = pairwise_analysis(question_df)

# View 60 first rows
first_60_rows = output_df[:60]
first_60_rows
# Out:
#       task                                          question1  \
# 0   access  What is the percentage of the rural population...
# 1   access  What is the percentage of the rural population...
# 2   access  What is the percentage of the rural population...
# 3   access  What is the percentage of the rural population...
# 4   access  What is the percentage of the rural population...
# 5   access  What is the percentage of the rural population...
# 6   access  What is the percentage of the rural population...
# 7   access  What is the percentage of the rural population...
# 8   access  What is the percentage of the rural population...
# 9   access  What is the percentage of the rural population...
# 10  access  What is the percentage of the rural population...
# 11  access  What is the percentage of the rural population...
# 12  access  What is the total rural population in Shikoku,...
# 13  access  What is the total rural population in Shikoku,...
# 14  access  What is the total rural population in Shikoku,...
# 15  access  What is the total rural population in Shikoku,...
# 16  access  What is the total rural population in Shikoku,...
# 17  access  What is the total rural population in Shikoku,...
# 18  access  What is the total rural population in Shikoku,...
# 19  access  What is the total rural population in Shikoku,...
# 20  access  What is the total rural population in Shikoku,...
# 21  access  What is the total rural population in Shikoku,...
# 22  access  What is the total rural population in Shikoku,...
# 23  access  What is the rural population within 2 kilomete...
# 24  access  What is the rural population within 2 kilomete...
# 25  access  What is the rural population within 2 kilomete...
# 26  access  What is the rural population within 2 kilomete...
# 27  access  What is the rural population within 2 kilomete...
# 28  access  What is the rural population within 2 kilomete...
# 29  access  What is the rural population within 2 kilomete...
# 30  access  What is the rural population within 2 kilomete...
# 31  access  What is the rural population within 2 kilomete...
# 32  access  What is the rural population within 2 kilomete...
# 33  access  What is the population within 2 kilometers of ...
# 34  access  What is the population within 2 kilometers of ...
# 35  access  What is the population within 2 kilometers of ...
# 36  access  What is the population within 2 kilometers of ...
# 37  access  What is the population within 2 kilometers of ...
# 38  access  What is the population within 2 kilometers of ...
# 39  access  What is the population within 2 kilometers of ...
# 40  access  What is the population within 2 kilometers of ...
# 41  access  What is the population within 2 kilometers of ...
# 42  access  What is the proportion of population within 2 ...
# 43  access  What is the proportion of population within 2 ...
# 44  access  What is the proportion of population within 2 ...
# 45  access  What is the proportion of population within 2 ...
# 46  access  What is the proportion of population within 2 ...
# 47  access  What is the proportion of population within 2 ...
# 48  access  What is the proportion of population within 2 ...
# 49  access  What is the proportion of population within 2 ...
# 50  access  What is the area of rural district within 2 ki...
# 51  access  What is the area of rural district within 2 ki...
# 52  access  What is the area of rural district within 2 ki...
# 53  access  What is the area of rural district within 2 ki...
# 54  access  What is the area of rural district within 2 ki...
# 55  access  What is the area of rural district within 2 ki...
# 56  access  What is the area of rural district within 2 ki...
# 57  access  What areas are within 2 kilometers of the all-...
# 58  access  What areas are within 2 kilometers of the all-...
# 59  access  What areas are within 2 kilometers of the all-...
#
#                                             question2  \
# 0   What is the total rural population in Shikoku,...
# 1   What is the rural population within 2 kilomete...
# 2   What is the population within 2 kilometers of ...
# 3   What is the proportion of population within 2 ...
# 4   What is the area of rural district within 2 ki...
# 5   What areas are within 2 kilometers of the all-...
# 6   What is the population for each rural district...
# 7   What are the areas within 2 kilometers of the ...
# 8    Where are the all-season roads in Shikoku, Japan
# 9   What is the population for each district in Sh...
# 10  What are the rural municipalities in Shikoku, ...
# 11  What are the metropolitan municipalities in Sh...
# 12  What is the rural population within 2 kilomete...
# 13  What is the population within 2 kilometers of ...
# 14  What is the proportion of population within 2 ...
# 15  What is the area of rural district within 2 ki...
# 16  What areas are within 2 kilometers of the all-...
# 17  What is the population for each rural district...
# 18  What are the areas within 2 kilometers of the ...
# 19   Where are the all-season roads in Shikoku, Japan
# 20  What is the population for each district in Sh...
# 21  What are the rural municipalities in Shikoku, ...
# 22  What are the metropolitan municipalities in Sh...
# 23  What is the population within 2 kilometers of ...
# 24  What is the proportion of population within 2 ...
# 25  What is the area of rural district within 2 ki...
# 26  What areas are within 2 kilometers of the all-...
# 27  What is the population for each rural district...
# 28  What are the areas within 2 kilometers of the ...
# 29   Where are the all-season roads in Shikoku, Japan
# 30  What is the population for each district in Sh...
# 31  What are the rural municipalities in Shikoku, ...
# 32  What are the metropolitan municipalities in Sh...
# 33  What is the proportion of population within 2 ...
# 34  What is the area of rural district within 2 ki...
# 35  What areas are within 2 kilometers of the all-...
# 36  What is the population for each rural district...
# 37  What are the areas within 2 kilometers of the ...
# 38   Where are the all-season roads in Shikoku, Japan
# 39  What is the population for each district in Sh...
# 40  What are the rural municipalities in Shikoku, ...
# 41  What are the metropolitan municipalities in Sh...
# 42  What is the area of rural district within 2 ki...
# 43  What areas are within 2 kilometers of the all-...
# 44  What is the population for each rural district...
# 45  What are the areas within 2 kilometers of the ...
# 46   Where are the all-season roads in Shikoku, Japan
# 47  What is the population for each district in Sh...
# 48  What are the rural municipalities in Shikoku, ...
# 49  What are the metropolitan municipalities in Sh...
# 50  What areas are within 2 kilometers of the all-...
# 51  What is the population for each rural district...
# 52  What are the areas within 2 kilometers of the ...
# 53   Where are the all-season roads in Shikoku, Japan
# 54  What is the population for each district in Sh...
# 55  What are the rural municipalities in Shikoku, ...
# 56  What are the metropolitan municipalities in Sh...
# 57  What is the population for each rural district...
# 58  What are the areas within 2 kilometers of the ...
# 59   Where are the all-season roads in Shikoku, Japan
#
#                                           parse_tree1  \
# 0   (start what is (measure (coreC genpro 0 ira_) ...
# 1   (start what is (measure (coreC genpro 0 ira_) ...
# 2   (start what is (measure (coreC genpro 0 ira_) ...
# 3   (start what is (measure (coreC genpro 0 ira_) ...
# 4   (start what is (measure (coreC genpro 0 ira_) ...
# 5   (start what is (measure (coreC genpro 0 ira_) ...
# 6   (start what is (measure (coreC genpro 0 ira_) ...
# 7   (start what is (measure (coreC genpro 0 ira_) ...
# 8   (start what is (measure (coreC genpro 0 ira_) ...
# 9   (start what is (measure (coreC genpro 0 ira_) ...
# 10  (start what is (measure (coreC genpro 0 ira_) ...
# 11  (start what is (measure (coreC genpro 0 ira_) ...
# 12  (start what is (measure (aggre aggregate 0) (c...
# 13  (start what is (measure (aggre aggregate 0) (c...
# 14  (start what is (measure (aggre aggregate 0) (c...
# 15  (start what is (measure (aggre aggregate 0) (c...
# 16  (start what is (measure (aggre aggregate 0) (c...
# 17  (start what is (measure (aggre aggregate 0) (c...
# 18  (start what is (measure (aggre aggregate 0) (c...
# 19  (start what is (measure (aggre aggregate 0) (c...
# 20  (start what is (measure (aggre aggregate 0) (c...
# 21  (start what is (measure (aggre aggregate 0) (c...
# 22  (start what is (measure (aggre aggregate 0) (c...
# 23  (start what is (measure (coreC objconamount 0 ...
# 24  (start what is (measure (coreC objconamount 0 ...
# 25  (start what is (measure (coreC objconamount 0 ...
# 26  (start what is (measure (coreC objconamount 0 ...
# 27  (start what is (measure (coreC objconamount 0 ...
# 28  (start what is (measure (coreC objconamount 0 ...
# 29  (start what is (measure (coreC objconamount 0 ...
# 30  (start what is (measure (coreC objconamount 0 ...
# 31  (start what is (measure (coreC objconamount 0 ...
# 32  (start what is (measure (coreC objconamount 0 ...
# 33  (start what is (measure (coreC objconamount 0 ...
# 34  (start what is (measure (coreC objconamount 0 ...
# 35  (start what is (measure (coreC objconamount 0 ...
# 36  (start what is (measure (coreC objconamount 0 ...
# 37  (start what is (measure (coreC objconamount 0 ...
# 38  (start what is (measure (coreC objconamount 0 ...
# 39  (start what is (measure (coreC objconamount 0 ...
# 40  (start what is (measure (coreC objconamount 0 ...
# 41  (start what is (measure (coreC objconamount 0 ...
# 42  (start what is (measure (coreC genpro 0 ira_) ...
# 43  (start what is (measure (coreC genpro 0 ira_) ...
# 44  (start what is (measure (coreC genpro 0 ira_) ...
# 45  (start what is (measure (coreC genpro 0 ira_) ...
# 46  (start what is (measure (coreC genpro 0 ira_) ...
# 47  (start what is (measure (coreC genpro 0 ira_) ...
# 48  (start what is (measure (coreC genpro 0 ira_) ...
# 49  (start what is (measure (coreC genpro 0 ira_) ...
# 50  (start what is (measure (coreC covamount 0 era...
# 51  (start what is (measure (coreC covamount 0 era...
# 52  (start what is (measure (coreC covamount 0 era...
# 53  (start what is (measure (coreC covamount 0 era...
# 54  (start what is (measure (coreC covamount 0 era...
# 55  (start what is (measure (coreC covamount 0 era...
# 56  (start what is (measure (coreC covamount 0 era...
# 57  (start (measure (location what areas)) are (co...
# 58  (start (measure (location what areas)) are (co...
# 59  (start (measure (location what areas)) are (co...
#
#                                           parse_tree2  \
# 0   (start what is (measure (aggre aggregate 0) (c...
# 1   (start what is (measure (coreC objconamount 0 ...
# 2   (start what is (measure (coreC objconamount 0 ...
# 3   (start what is (measure (coreC genpro 0 ira_) ...
# 4   (start what is (measure (coreC covamount 0 era...
# 5   (start (measure (location what areas)) are (co...
# 6   (start what is (measure (coreC objconamount 0 ...
# 7   (start what are (measure (coreC region 0)) (co...
# 8   (start (measure (location where are (coreC obj...
# 9   (start what is (measure (coreC objconamount 0 ...
# 10  (start what are (measure (coreC object 0)) (ex...
# 11  (start what are (measure (coreC object 0)) (ex...
# 12  (start what is (measure (coreC objconamount 0 ...
# 13  (start what is (measure (coreC objconamount 0 ...
# 14  (start what is (measure (coreC genpro 0 ira_) ...
# 15  (start what is (measure (coreC covamount 0 era...
# 16  (start (measure (location what areas)) are (co...
# 17  (start what is (measure (coreC objconamount 0 ...
# 18  (start what are (measure (coreC region 0)) (co...
# 19  (start (measure (location where are (coreC obj...
# 20  (start what is (measure (coreC objconamount 0 ...
# 21  (start what are (measure (coreC object 0)) (ex...
# 22  (start what are (measure (coreC object 0)) (ex...
# 23  (start what is (measure (coreC objconamount 0 ...
# 24  (start what is (measure (coreC genpro 0 ira_) ...
# 25  (start what is (measure (coreC covamount 0 era...
# 26  (start (measure (location what areas)) are (co...
# 27  (start what is (measure (coreC objconamount 0 ...
# 28  (start what are (measure (coreC region 0)) (co...
# 29  (start (measure (location where are (coreC obj...
# 30  (start what is (measure (coreC objconamount 0 ...
# 31  (start what are (measure (coreC object 0)) (ex...
# 32  (start what are (measure (coreC object 0)) (ex...
# 33  (start what is (measure (coreC genpro 0 ira_) ...
# 34  (start what is (measure (coreC covamount 0 era...
# 35  (start (measure (location what areas)) are (co...
# 36  (start what is (measure (coreC objconamount 0 ...
# 37  (start what are (measure (coreC region 0)) (co...
# 38  (start (measure (location where are (coreC obj...
# 39  (start what is (measure (coreC objconamount 0 ...
# 40  (start what are (measure (coreC object 0)) (ex...
# 41  (start what are (measure (coreC object 0)) (ex...
# 42  (start what is (measure (coreC covamount 0 era...
# 43  (start (measure (location what areas)) are (co...
# 44  (start what is (measure (coreC objconamount 0 ...
# 45  (start what are (measure (coreC region 0)) (co...
# 46  (start (measure (location where are (coreC obj...
# 47  (start what is (measure (coreC objconamount 0 ...
# 48  (start what are (measure (coreC object 0)) (ex...
# 49  (start what are (measure (coreC object 0)) (ex...
# 50  (start (measure (location what areas)) are (co...
# 51  (start what is (measure (coreC objconamount 0 ...
# 52  (start what are (measure (coreC region 0)) (co...
# 53  (start (measure (location where are (coreC obj...
# 54  (start what is (measure (coreC objconamount 0 ...
# 55  (start what are (measure (coreC object 0)) (ex...
# 56  (start what are (measure (coreC object 0)) (ex...
# 57  (start what is (measure (coreC objconamount 0 ...
# 58  (start what are (measure (coreC region 0)) (co...
# 59  (start (measure (location where are (coreC obj...
#
#                                                nodes1  \
# 0   /urbanization, SelectLayerByAttribute, /urbani...
# 1   /urbanization, SelectLayerByAttribute, /urbani...
# 2   /urbanization, SelectLayerByAttribute, /urbani...
# 3   /urbanization, SelectLayerByAttribute, /urbani...
# 4   /urbanization, SelectLayerByAttribute, /urbani...
# 5   /urbanization, SelectLayerByAttribute, /urbani...
# 6   /urbanization, SelectLayerByAttribute, /urbani...
# 7   /urbanization, SelectLayerByAttribute, /urbani...
# 8   /urbanization, SelectLayerByAttribute, /urbani...
# 9   /urbanization, SelectLayerByAttribute, /urbani...
# 10  /urbanization, SelectLayerByAttribute, /urbani...
# 11  /urbanization, SelectLayerByAttribute, /urbani...
# 12  /urbanization, SelectLayerByAttribute, /urbani...
# 13  /urbanization, SelectLayerByAttribute, /urbani...
# 14  /urbanization, SelectLayerByAttribute, /urbani...
# 15  /urbanization, SelectLayerByAttribute, /urbani...
# 16  /urbanization, SelectLayerByAttribute, /urbani...
# 17  /urbanization, SelectLayerByAttribute, /urbani...
# 18  /urbanization, SelectLayerByAttribute, /urbani...
# 19  /urbanization, SelectLayerByAttribute, /urbani...
# 20  /urbanization, SelectLayerByAttribute, /urbani...
# 21  /urbanization, SelectLayerByAttribute, /urbani...
# 22  /urbanization, SelectLayerByAttribute, /urbani...
# 23  /urbanization, SelectLayerByAttribute, /urbani...
# 24  /urbanization, SelectLayerByAttribute, /urbani...
# 25  /urbanization, SelectLayerByAttribute, /urbani...
# 26  /urbanization, SelectLayerByAttribute, /urbani...
# 27  /urbanization, SelectLayerByAttribute, /urbani...
# 28  /urbanization, SelectLayerByAttribute, /urbani...
# 29  /urbanization, SelectLayerByAttribute, /urbani...
# 30  /urbanization, SelectLayerByAttribute, /urbani...
# 31  /urbanization, SelectLayerByAttribute, /urbani...
# 32  /urbanization, SelectLayerByAttribute, /urbani...
# 33  /urbanization, SelectLayerByAttribute, /urbani...
# 34  /urbanization, SelectLayerByAttribute, /urbani...
# 35  /urbanization, SelectLayerByAttribute, /urbani...
# 36  /urbanization, SelectLayerByAttribute, /urbani...
# 37  /urbanization, SelectLayerByAttribute, /urbani...
# 38  /urbanization, SelectLayerByAttribute, /urbani...
# 39  /urbanization, SelectLayerByAttribute, /urbani...
# 40  /urbanization, SelectLayerByAttribute, /urbani...
# 41  /urbanization, SelectLayerByAttribute, /urbani...
# 42  /urbanization, SelectLayerByAttribute, /urbani...
# 43  /urbanization, SelectLayerByAttribute, /urbani...
# 44  /urbanization, SelectLayerByAttribute, /urbani...
# 45  /urbanization, SelectLayerByAttribute, /urbani...
# 46  /urbanization, SelectLayerByAttribute, /urbani...
# 47  /urbanization, SelectLayerByAttribute, /urbani...
# 48  /urbanization, SelectLayerByAttribute, /urbani...
# 49  /urbanization, SelectLayerByAttribute, /urbani...
# 50  /urbanization, SelectLayerByAttribute, /urbani...
# 51  /urbanization, SelectLayerByAttribute, /urbani...
# 52  /urbanization, SelectLayerByAttribute, /urbani...
# 53  /urbanization, SelectLayerByAttribute, /urbani...
# 54  /urbanization, SelectLayerByAttribute, /urbani...
# 55  /urbanization, SelectLayerByAttribute, /urbani...
# 56  /urbanization, SelectLayerByAttribute, /urbani...
# 57  /urbanization, SelectLayerByAttribute, /urbani...
# 58  /urbanization, SelectLayerByAttribute, /urbani...
# 59  /urbanization, SelectLayerByAttribute, /urbani...
#
#                                                nodes2  question_sim_SBERT  \
# 0   /urbanization, SelectLayerByAttribute, /urbani...            0.904799
# 1   /urbanization, SelectLayerByAttribute, /urbani...            0.990467
# 2   /urbanization, SelectLayerByAttribute, /urbani...            0.985850
# 3   /urbanization, SelectLayerByAttribute, /urbani...            0.989975
# 4   /urbanization, SelectLayerByAttribute, /urbani...            0.975830
# 5   /urbanization, SelectLayerByAttribute, /urbani...            0.977657
# 6   /urbanization, SelectLayerByAttribute, /urbani...            0.899259
# 7                       /roads, Buffer, /roads_buffer            0.920201
# 8                                              /roads            0.843195
# 9                                         /chochomoku            0.797812
# 10  /urbanization, SelectLayerByAttribute, /urbani...            0.876407
# 11                                      /urbanization            0.761016
# 12  /urbanization, SelectLayerByAttribute, /urbani...            0.898734
# 13  /urbanization, SelectLayerByAttribute, /urbani...            0.891675
# 14  /urbanization, SelectLayerByAttribute, /urbani...            0.894127
# 15  /urbanization, SelectLayerByAttribute, /urbani...            0.890053
# 16  /urbanization, SelectLayerByAttribute, /urbani...            0.883588
# 17  /urbanization, SelectLayerByAttribute, /urbani...            0.974695
# 18                      /roads, Buffer, /roads_buffer            0.795070
# 19                                             /roads            0.797058
# 20                                        /chochomoku            0.856557
# 21  /urbanization, SelectLayerByAttribute, /urbani...            0.962271
# 22                                      /urbanization            0.808233
# 23  /urbanization, SelectLayerByAttribute, /urbani...            0.983737
# 24  /urbanization, SelectLayerByAttribute, /urbani...            0.979709
# 25  /urbanization, SelectLayerByAttribute, /urbani...            0.990142
# 26  /urbanization, SelectLayerByAttribute, /urbani...            0.982604
# 27  /urbanization, SelectLayerByAttribute, /urbani...            0.888170
# 28                      /roads, Buffer, /roads_buffer            0.928242
# 29                                             /roads            0.852698
# 30                                        /chochomoku            0.780056
# 31  /urbanization, SelectLayerByAttribute, /urbani...            0.885201
# 32                                      /urbanization            0.752654
# 33  /urbanization, SelectLayerByAttribute, /urbani...            0.996195
# 34  /urbanization, SelectLayerByAttribute, /urbani...            0.978764
# 35  /urbanization, SelectLayerByAttribute, /urbani...            0.994605
# 36  /urbanization, SelectLayerByAttribute, /urbani...            0.910526
# 37                      /roads, Buffer, /roads_buffer            0.937688
# 38                                             /roads            0.867624
# 39                                        /chochomoku            0.826066
# 40  /urbanization, SelectLayerByAttribute, /urbani...            0.873187
# 41                                      /urbanization            0.784117
# 42  /urbanization, SelectLayerByAttribute, /urbani...            0.970883
# 43  /urbanization, SelectLayerByAttribute, /urbani...            0.986561
# 44  /urbanization, SelectLayerByAttribute, /urbani...            0.911117
# 45                      /roads, Buffer, /roads_buffer            0.924996
# 46                                             /roads            0.854301
# 47                                        /chochomoku            0.821469
# 48  /urbanization, SelectLayerByAttribute, /urbani...            0.867286
# 49                                      /urbanization            0.776003
# 50  /urbanization, SelectLayerByAttribute, /urbani...            0.985228
# 51  /urbanization, SelectLayerByAttribute, /urbani...            0.887071
# 52                      /roads, Buffer, /roads_buffer            0.941662
# 53                                             /roads            0.871530
# 54                                        /chochomoku            0.792130
# 55  /urbanization, SelectLayerByAttribute, /urbani...            0.890723
# 56                                      /urbanization            0.774869
# 57  /urbanization, SelectLayerByAttribute, /urbani...            0.900698
# 58                      /roads, Buffer, /roads_buffer            0.948196
# 59                                             /roads            0.880177
#
#     parse_tree_dist                               question_subtraction  \
# 0          0.414634  percentage of within 2 kilometers of all-seaso...
# 1          0.098039                                         percentage
# 2          0.132075                                         percentage
# 3          0.034483                                         percentage
# 4          0.090909                              percentage population
# 5          0.274510                           is percentage population
# 6          0.450000  percentage of within 2 kilometers of all-seaso...
# 7          0.160000                     is percentage rural population
# 8          0.578947  What is percentage of rural population within ...
# 9          0.450000  percentage of rural within 2 kilometers of all...
# 10         0.567568  is percentage of population within 2 kilometer...
# 11         0.567568  is percentage of rural population within 2 kil...
# 12         0.444444                                              total
# 13         0.473684                                              total
# 14         0.441860                                              total
# 15         0.475000                                   total population
# 16         0.472222                                is total population
# 17         0.200000                                              total
# 18         0.457143                          is total rural population
# 19         0.347826                     What is total rural population
# 20         0.200000                                        total rural
# 21         0.272727                                is total population
# 22         0.272727                          is total rural population
# 23         0.041667
# 24         0.132075
# 25         0.140000                                         population
# 26         0.195652                                      is population
# 27         0.371429            within 2 kilometers of all-season roads
# 28         0.066667                                is rural population
# 29         0.515152    What is rural population within 2 kilometers of
# 30         0.371429      rural within 2 kilometers of all-season roads
# 31         0.500000  is population within 2 kilometers of all-seaso...
# 32         0.500000  is rural population within 2 kilometers of all...
# 33         0.090909
# 34         0.173077                                population for each
# 35         0.145833                                      is population
# 36         0.351351            within 2 kilometers of all-season roads
# 37         0.106383              is population for each rural district
# 38         0.542857  What is population within 2 kilometers of for ...
# 39         0.351351      within 2 kilometers of all-season roads rural
# 40         0.529412  is population within 2 kilometers of all-seaso...
# 41         0.529412  is population within 2 kilometers of all-seaso...
# 42         0.122807                     proportion population for each
# 43         0.226415                           is proportion population
# 44         0.428571  proportion of within 2 kilometers of all-seaso...
# 45         0.192308   is proportion population for each rural district
# 46         0.600000  What is proportion of population within 2 kilo...
# 47         0.428571  proportion of within 2 kilometers of all-seaso...
# 48         0.589744  is proportion of population within 2 kilometer...
# 49         0.589744  is proportion of population within 2 kilometer...
# 50         0.280000                                            is area
# 51         0.487179    area of within 2 kilometers of all-season roads
# 52         0.163265                             is area rural district
# 53         0.567568  What is area of rural district within 2 kilome...
# 54         0.487179  area of rural within 2 kilometers of all-seaso...
# 55         0.527778  is area of district within 2 kilometers of all...
# 56         0.527778  is area of rural district within 2 kilometers ...
# 57         0.457143  areas are within 2 kilometers of all-season roads
# 58         0.177778                            for each rural district
# 59         0.515152  What areas within 2 kilometers of for each rur...
#
#                                     nodes_subtraction
# 0   [Clip, /roads, Buffer, /roads_buffer, /rural_2...
# 1   [AddFields, CalculateField, CalculateField, Su...
# 2   [AddFields, CalculateField, CalculateField, Ca...
# 3   [AddFields, CalculateField, CalculateField, Ca...
# 4   [AddFields, CalculateField, CalculateField, Ca...
# 5   [AddFields, AddFields, /rural_2km_addfields, C...
# 6   [Clip, /roads, Buffer, /roads_buffer, /rural_2...
# 7   [/urbanization, SelectLayerByAttribute, /urban...
# 8   [/urbanization, SelectLayerByAttribute, /urban...
# 9   [/urbanization, SelectLayerByAttribute, /urban...
# 10  [/chochomoku, Clip, Clip, /rural_clip, /roads,...
# 11  [SelectLayerByAttribute, /urbanization_select,...
# 12  [/rural_clip_popsum, /rural_clip_popsum_addfie...
# 13  [/rural_clip_popsum, /rural_clip_popsum_addfie...
# 14  [SummaryStatistics, /rural_clip_popsum, /rural...
# 15  [SummaryStatistics, /rural_clip_popsum, /rural...
# 16  [SummaryStatistics, /rural_clip_popsum, AddFie...
# 17  [SummaryStatistics, /rural_clip_popsum, AddFie...
# 18  [/urbanization, SelectLayerByAttribute, /urban...
# 19  [/urbanization, SelectLayerByAttribute, /urban...
# 20  [/urbanization, SelectLayerByAttribute, /urban...
# 21  [/chochomoku, Clip, /rural_clip, SummaryStatis...
# 22  [SelectLayerByAttribute, /urbanization_select,...
# 23  [CalculateField, AddField, /rural_2km_pop_sum_...
# 24  [CalculateField, SummaryStatistics, /rural_2km...
# 25  [CalculateField, CalculateField, /rural_2km_po...
# 26  [AddFields, /rural_2km_addfields, CalculateFie...
# 27  [Clip, /roads, Buffer, /roads_buffer, /rural_2...
# 28  [/urbanization, SelectLayerByAttribute, /urban...
# 29  [/urbanization, SelectLayerByAttribute, /urban...
# 30  [/urbanization, SelectLayerByAttribute, /urban...
# 31  [/chochomoku, Clip, Clip, /rural_clip, /roads,...
# 32  [SelectLayerByAttribute, /urbanization_select,...
# 33            [SummaryStatistics, /rural_2km_pop_sum]
# 34  [CalculateField, /rural_2km_pop_est, SummarySt...
# 35  [AddFields, /rural_2km_addfields, CalculateFie...
# 36  [Clip, /roads, Buffer, /roads_buffer, /rural_2...
# 37  [/urbanization, SelectLayerByAttribute, /urban...
# 38  [/urbanization, SelectLayerByAttribute, /urban...
# 39  [/urbanization, SelectLayerByAttribute, /urban...
# 40  [/chochomoku, Clip, Clip, /rural_clip, /roads,...
# 41  [SelectLayerByAttribute, /urbanization_select,...
# 42               [CalculateField, /rural_2km_pop_est]
# 43  [AddFields, /rural_2km_addfields, CalculateFie...
# 44  [Clip, /roads, Buffer, /roads_buffer, /rural_2...
# 45  [/urbanization, SelectLayerByAttribute, /urban...
# 46  [/urbanization, SelectLayerByAttribute, /urban...
# 47  [/urbanization, SelectLayerByAttribute, /urban...
# 48  [/chochomoku, Clip, Clip, /rural_clip, /roads,...
# 49  [SelectLayerByAttribute, /urbanization_select,...
# 50  [AddFields, /rural_2km_addfields, CalculateFie...
# 51  [Clip, /roads, Buffer, /roads_buffer, /rural_2...
# 52  [/urbanization, SelectLayerByAttribute, /urban...
# 53  [/urbanization, SelectLayerByAttribute, /urban...
# 54  [/urbanization, SelectLayerByAttribute, /urban...
# 55  [/chochomoku, Clip, Clip, /rural_clip, /roads,...
# 56  [SelectLayerByAttribute, /urbanization_select,...
# 57  [Clip, /roads, Buffer, /roads_buffer, /rural_2km]
# 58  [/urbanization, SelectLayerByAttribute, /urban...
# 59  [/urbanization, SelectLayerByAttribute, /urban...

# %%
# Save df to an excel file
output_df.to_excel("analysis_df.xlsx", index = False)

# %%
# Open again the data set in order to filter it out 
subworkflows_df = pd.read_excel("analysis_df.xlsx", engine = "openpyxl")

# %%
# Define a function to check if one workflow is subset of another 
def is_subset(row):
    return all(item in row['nodes1'] for item in row['nodes2'])

# Apply the function to create a new column 'subset_check'
subworkflows_df['subset_check'] = subworkflows_df.apply(is_subset, axis=1)

# Filter and keep only the rows with 'subset_check' equal to true
filtered_df = subworkflows_df[subworkflows_df['subset_check']]

# %%
filtered_df
# Out:
#        task                                          question1  \
# 0    access  What is the percentage of the rural population...
# 1    access  What is the percentage of the rural population...
# 2    access  What is the percentage of the rural population...
# 3    access  What is the percentage of the rural population...
# 4    access  What is the percentage of the rural population...
# ..      ...                                                ...
# 243   solar  What are the rooftop cells with slope lower th...
# 244   solar  What are the rooftop cells with slope lower th...
# 246   solar  What are the rooftop cells with slope lower th...
# 247   solar  What are the rooftop cells with slope lower th...
# 253   solar  What is the solar radiation in KWh/m2 for each...
#
#                                              question2  \
# 0    What is the total rural population in Shikoku,...
# 1    What is the rural population within 2 kilomete...
# 2    What is the population within 2 kilometers of ...
# 3    What is the proportion of population within 2 ...
# 4    What is the area of rural district within 2 ki...
# ..                                                 ...
# 243  What is the solar radiation in Wh/m2 for each ...
# 244  What are the slopes in Glover Park, Washington...
# 246  What is the solar radiation in KWh/m2 for each...
# 247  What is the solar radiation in Wh/m2 for each ...
# 253  What is the solar radiation in Wh/m2 for each ...
#
#                                            parse_tree1  \
# 0    (start what is (measure (coreC genpro 0 ira_) ...
# 1    (start what is (measure (coreC genpro 0 ira_) ...
# 2    (start what is (measure (coreC genpro 0 ira_) ...
# 3    (start what is (measure (coreC genpro 0 ira_) ...
# 4    (start what is (measure (coreC genpro 0 ira_) ...
# ..                                                 ...
# 243  (start what are (measure (coreC object 0)) (co...
# 244  (start what are (measure (coreC object 0)) (co...
# 246  (start what are (measure (coreC object 0)) (co...
# 247  (start what are (measure (coreC object 0)) (co...
# 253  (start what is (measure (coreC conamount 0 era...
#
#                                            parse_tree2  \
# 0    (start what is (measure (aggre aggregate 0) (c...
# 1    (start what is (measure (coreC objconamount 0 ...
# 2    (start what is (measure (coreC objconamount 0 ...
# 3    (start what is (measure (coreC genpro 0 ira_) ...
# 4    (start what is (measure (coreC covamount 0 era...
# ..                                                 ...
# 243  (start what is (measure (coreC conamount 0 era...
# 244  (start what are (measure (coreC field 0 rat_))...
# 246  (start what is (measure (coreC conamount 0 era...
# 247  (start what is (measure (coreC conamount 0 era...
# 253  (start what is (measure (coreC conamount 0 era...
#
#                                                 nodes1  \
# 0    /urbanization, SelectLayerByAttribute, /urbani...
# 1    /urbanization, SelectLayerByAttribute, /urbani...
# 2    /urbanization, SelectLayerByAttribute, /urbani...
# 3    /urbanization, SelectLayerByAttribute, /urbani...
# 4    /urbanization, SelectLayerByAttribute, /urbani...
# ..                                                 ...
# 243  /solar_rad, RasterCalculator, /solar_rad_kwh, ...
# 244  /solar_rad, RasterCalculator, /solar_rad_kwh, ...
# 246  /solar_rad, RasterCalculator, /solar_rad_kwh, ...
# 247  /solar_rad, RasterCalculator, /solar_rad_kwh, ...
# 253       /solar_rad, RasterCalculator, /solar_rad_kwh
#
#                                                 nodes2  question_sim_SBERT  \
# 0    /urbanization, SelectLayerByAttribute, /urbani...            0.904799
# 1    /urbanization, SelectLayerByAttribute, /urbani...            0.990467
# 2    /urbanization, SelectLayerByAttribute, /urbani...            0.985850
# 3    /urbanization, SelectLayerByAttribute, /urbani...            0.989975
# 4    /urbanization, SelectLayerByAttribute, /urbani...            0.975830
# ..                                                 ...                 ...
# 243                                         /solar_rad            0.890799
# 244                            /dsm, Slope, /dsm_slope            0.816133
# 246       /solar_rad, RasterCalculator, /solar_rad_kwh            0.820802
# 247                                         /solar_rad            0.822046
# 253                                         /solar_rad            0.997037
#
#      parse_tree_dist                               question_subtraction  \
# 0           0.414634  percentage of within 2 kilometers of all-seaso...
# 1           0.098039                                         percentage
# 2           0.132075                                         percentage
# 3           0.034483                                         percentage
# 4           0.090909                              percentage population
# ..               ...                                                ...
# 243         0.586957  are cells with slope lower than 45 degrees and...
# 244         0.387097     rooftop cells with slope lower than 45 degrees
# 246         0.454545         are cells with slope lower than 45 degrees
# 247         0.454545         are cells with slope lower than 45 degrees
# 253         0.000000                                             KWh/m2
#
#                                      nodes_subtraction  subset_check
# 0    ['Clip', '/roads', 'Buffer', '/roads_buffer', ...          True
# 1    ['AddFields', 'CalculateField', 'CalculateFiel...          True
# 2    ['AddFields', 'CalculateField', 'CalculateFiel...          True
# 3    ['AddFields', 'CalculateField', 'CalculateFiel...          True
# 4    ['AddFields', 'CalculateField', 'CalculateFiel...          True
# ..                                                 ...           ...
# 243  ['RasterCalculator', '/solar_rad_kwh', '/dsm',...          True
# 244  ['/solar_rad', 'RasterCalculator', '/solar_rad...          True
# 246  ['/dsm', 'Slope', '/dsm_slope', 'Con', '/dsm_r...          True
# 247  ['RasterCalculator', '/solar_rad_kwh', '/dsm',...          True
# 253             ['RasterCalculator', '/solar_rad_kwh']          True
#
# [195 rows x 12 columns]

# %%
##### Eliminate data nodes (comes with a / before it) and only keep the tools ####

# Define a function to remove items starting with '/'
def remove_slash_items(row):
    return [item for item in row if not item.startswith('/')]

# Create a copy of the df
filtered_df_copy = filtered_df.copy()

# Convert the items in 'nodes_subtraction' column to lists
filtered_df_copy['nodes_subtraction'] = filtered_df_copy['nodes_subtraction'].apply(eval)

# Apply the function to the 'nodes_subtraction' column using .loc
filtered_df_copy.loc[:, 'nodes_subtraction'] = filtered_df_copy['nodes_subtraction'].apply(remove_slash_items)

# %%
filtered_df_copy
# Out:
#        task                                          question1  \
# 0    access  What is the percentage of the rural population...
# 1    access  What is the percentage of the rural population...
# 2    access  What is the percentage of the rural population...
# 3    access  What is the percentage of the rural population...
# 4    access  What is the percentage of the rural population...
# ..      ...                                                ...
# 243   solar  What are the rooftop cells with slope lower th...
# 244   solar  What are the rooftop cells with slope lower th...
# 246   solar  What are the rooftop cells with slope lower th...
# 247   solar  What are the rooftop cells with slope lower th...
# 253   solar  What is the solar radiation in KWh/m2 for each...
#
#                                              question2  \
# 0    What is the total rural population in Shikoku,...
# 1    What is the rural population within 2 kilomete...
# 2    What is the population within 2 kilometers of ...
# 3    What is the proportion of population within 2 ...
# 4    What is the area of rural district within 2 ki...
# ..                                                 ...
# 243  What is the solar radiation in Wh/m2 for each ...
# 244  What are the slopes in Glover Park, Washington...
# 246  What is the solar radiation in KWh/m2 for each...
# 247  What is the solar radiation in Wh/m2 for each ...
# 253  What is the solar radiation in Wh/m2 for each ...
#
#                                            parse_tree1  \
# 0    (start what is (measure (coreC genpro 0 ira_) ...
# 1    (start what is (measure (coreC genpro 0 ira_) ...
# 2    (start what is (measure (coreC genpro 0 ira_) ...
# 3    (start what is (measure (coreC genpro 0 ira_) ...
# 4    (start what is (measure (coreC genpro 0 ira_) ...
# ..                                                 ...
# 243  (start what are (measure (coreC object 0)) (co...
# 244  (start what are (measure (coreC object 0)) (co...
# 246  (start what are (measure (coreC object 0)) (co...
# 247  (start what are (measure (coreC object 0)) (co...
# 253  (start what is (measure (coreC conamount 0 era...
#
#                                            parse_tree2  \
# 0    (start what is (measure (aggre aggregate 0) (c...
# 1    (start what is (measure (coreC objconamount 0 ...
# 2    (start what is (measure (coreC objconamount 0 ...
# 3    (start what is (measure (coreC genpro 0 ira_) ...
# 4    (start what is (measure (coreC covamount 0 era...
# ..                                                 ...
# 243  (start what is (measure (coreC conamount 0 era...
# 244  (start what are (measure (coreC field 0 rat_))...
# 246  (start what is (measure (coreC conamount 0 era...
# 247  (start what is (measure (coreC conamount 0 era...
# 253  (start what is (measure (coreC conamount 0 era...
#
#                                                 nodes1  \
# 0    /urbanization, SelectLayerByAttribute, /urbani...
# 1    /urbanization, SelectLayerByAttribute, /urbani...
# 2    /urbanization, SelectLayerByAttribute, /urbani...
# 3    /urbanization, SelectLayerByAttribute, /urbani...
# 4    /urbanization, SelectLayerByAttribute, /urbani...
# ..                                                 ...
# 243  /solar_rad, RasterCalculator, /solar_rad_kwh, ...
# 244  /solar_rad, RasterCalculator, /solar_rad_kwh, ...
# 246  /solar_rad, RasterCalculator, /solar_rad_kwh, ...
# 247  /solar_rad, RasterCalculator, /solar_rad_kwh, ...
# 253       /solar_rad, RasterCalculator, /solar_rad_kwh
#
#                                                 nodes2  question_sim_SBERT  \
# 0    /urbanization, SelectLayerByAttribute, /urbani...            0.904799
# 1    /urbanization, SelectLayerByAttribute, /urbani...            0.990467
# 2    /urbanization, SelectLayerByAttribute, /urbani...            0.985850
# 3    /urbanization, SelectLayerByAttribute, /urbani...            0.989975
# 4    /urbanization, SelectLayerByAttribute, /urbani...            0.975830
# ..                                                 ...                 ...
# 243                                         /solar_rad            0.890799
# 244                            /dsm, Slope, /dsm_slope            0.816133
# 246       /solar_rad, RasterCalculator, /solar_rad_kwh            0.820802
# 247                                         /solar_rad            0.822046
# 253                                         /solar_rad            0.997037
#
#      parse_tree_dist                               question_subtraction  \
# 0           0.414634  percentage of within 2 kilometers of all-seaso...
# 1           0.098039                                         percentage
# 2           0.132075                                         percentage
# 3           0.034483                                         percentage
# 4           0.090909                              percentage population
# ..               ...                                                ...
# 243         0.586957  are cells with slope lower than 45 degrees and...
# 244         0.387097     rooftop cells with slope lower than 45 degrees
# 246         0.454545         are cells with slope lower than 45 degrees
# 247         0.454545         are cells with slope lower than 45 degrees
# 253         0.000000                                             KWh/m2
#
#                                      nodes_subtraction  subset_check
# 0    [Clip, Buffer, AddFields, CalculateField, Calc...          True
# 1    [AddFields, CalculateField, CalculateField, Su...          True
# 2    [AddFields, CalculateField, CalculateField, Ca...          True
# 3    [AddFields, CalculateField, CalculateField, Ca...          True
# 4    [AddFields, CalculateField, CalculateField, Ca...          True
# ..                                                 ...           ...
# 243                [RasterCalculator, Slope, Con, Con]          True
# 244                            [RasterCalculator, Con]          True
# 246                                       [Slope, Con]          True
# 247                     [RasterCalculator, Slope, Con]          True
# 253                                 [RasterCalculator]          True
#
# [195 rows x 12 columns]

# %%
# Save the final df to an excel file
filtered_df_copy.to_excel("analysis_df_filtered.xlsx", index = False)
